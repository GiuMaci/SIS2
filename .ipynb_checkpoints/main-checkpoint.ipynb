# %%
import sys
import os

# Suppose you have a relative path like 'data/files'
relative_path = "src/alignment"

# Get the absolute path
absolute_path = os.path.abspath(relative_path)
original_path=sys.path
sys.path.append(absolute_path)
print("Absolute path:", absolute_path)
# Out:
# Absolute path: /home/serverKB/SIS/src/alignment

# %%
import referenceAlignments as refAl  # Adjust function name as needed
refAl.parser(absolute_path)

names = []

# Loop through each file in the directory
for filename in os.listdir(absolute_path):
    if filename.endswith('.rdf'):
        names.append(filename.split('.')[0])

# Print the list of .rdf files
print("List of .rdf files:", names)
# Out:
# List of .rdf files: ['iasted-sigkdd', 'edas-ekaw', 'cmt-edas', 'cmt-iasted', 'conference-edas', 'cmt-ekaw', 'ekaw-iasted', 'edas-iasted', 'confOf-iasted', 'confOf-ekaw', 'edas-sigkdd', 'confOf-edas', 'conference-ekaw', 'conference-sigkdd', 'cmt-confOf', 'ekaw-sigkdd', 'conference-confOf', 'cmt-conference', 'confOf-sigkdd', 'cmt-sigkdd', 'conference-iasted']
# Found RDF files: ['iasted-sigkdd.rdf', 'edas-ekaw.rdf', 'cmt-edas.rdf', 'cmt-iasted.rdf', 'conference-edas.rdf', 'cmt-ekaw.rdf', 'ekaw-iasted.rdf', 'edas-iasted.rdf', 'confOf-iasted.rdf', 'confOf-ekaw.rdf', 'edas-sigkdd.rdf', 'confOf-edas.rdf', 'conference-ekaw.rdf', 'conference-sigkdd.rdf', 'cmt-confOf.rdf', 'ekaw-sigkdd.rdf', 'conference-confOf.rdf', 'cmt-conference.rdf', 'confOf-sigkdd.rdf', 'cmt-sigkdd.rdf', 'conference-iasted.rdf']
# CSV file "/home/serverKB/SIS/src/alignment/iasted-sigkdd-referencealignment.csv" has been created and populated.
# CSV file "/home/serverKB/SIS/src/alignment/edas-ekaw-referencealignment.csv" has been created and populated.
# CSV file "/home/serverKB/SIS/src/alignment/cmt-edas-referencealignment.csv" has been created and populated.
# CSV file "/home/serverKB/SIS/src/alignment/cmt-iasted-referencealignment.csv" has been created and populated.
# CSV file "/home/serverKB/SIS/src/alignment/conference-edas-referencealignment.csv" has been created and populated.
# CSV file "/home/serverKB/SIS/src/alignment/cmt-ekaw-referencealignment.csv" has been created and populated.
# CSV file "/home/serverKB/SIS/src/alignment/ekaw-iasted-referencealignment.csv" has been created and populated.
# CSV file "/home/serverKB/SIS/src/alignment/edas-iasted-referencealignment.csv" has been created and populated.
# CSV file "/home/serverKB/SIS/src/alignment/confOf-iasted-referencealignment.csv" has been created and populated.
# CSV file "/home/serverKB/SIS/src/alignment/confOf-ekaw-referencealignment.csv" has been created and populated.
# CSV file "/home/serverKB/SIS/src/alignment/edas-sigkdd-referencealignment.csv" has been created and populated.
# CSV file "/home/serverKB/SIS/src/alignment/confOf-edas-referencealignment.csv" has been created and populated.
# CSV file "/home/serverKB/SIS/src/alignment/conference-ekaw-referencealignment.csv" has been created and populated.
# CSV file "/home/serverKB/SIS/src/alignment/conference-sigkdd-referencealignment.csv" has been created and populated.
# CSV file "/home/serverKB/SIS/src/alignment/cmt-confOf-referencealignment.csv" has been created and populated.
# CSV file "/home/serverKB/SIS/src/alignment/ekaw-sigkdd-referencealignment.csv" has been created and populated.
# An error occurred while parsing conference-confOf.rdf: file:///home/serverKB/SIS/src/alignment/conference-confOf.rdf:11:4: Invalid property attribute URI: http://www.w3.org/1999/02/22-rdf-syntax-ns#about
# CSV file "/home/serverKB/SIS/src/alignment/cmt-conference-referencealignment.csv" has been created and populated.
# CSV file "/home/serverKB/SIS/src/alignment/confOf-sigkdd-referencealignment.csv" has been created and populated.
# CSV file "/home/serverKB/SIS/src/alignment/cmt-sigkdd-referencealignment.csv" has been created and populated.
# CSV file "/home/serverKB/SIS/src/alignment/conference-iasted-referencealignment.csv" has been created and populated.
# Parsing completed.
# List of .rdf files: ['iasted-sigkdd', 'edas-ekaw', 'cmt-edas', 'cmt-iasted', 'conference-edas', 'cmt-ekaw', 'ekaw-iasted', 'edas-iasted', 'confOf-iasted', 'confOf-ekaw', 'edas-sigkdd', 'confOf-edas', 'conference-ekaw', 'conference-sigkdd', 'cmt-confOf', 'ekaw-sigkdd', 'conference-confOf', 'cmt-conference', 'confOf-sigkdd', 'cmt-sigkdd', 'conference-iasted']

# %%
relative_path = "src/textExtraction"
absolute_path = os.path.abspath(relative_path)
sys.path = original_path
sys.path.append(absolute_path)

import textExtractor as texEx
import os



# Loop through each file in the directory


# Print the list of .rdf files
print("List of .rdf files:", names)

for filename in os.listdir(absolute_path):
    filepath = os.path.join(absolute_path, filename)  # Get full path
    if os.path.isfile(filepath):
         if filename.endswith(".owl"):# Check if it's a file
            print("File:", filename)
            print(filename.split('.owl')[0])
            texEx.genrelatedtxt(filename.split('.owl')[0])
# Out:
# List of .rdf files: ['iasted-sigkdd', 'edas-ekaw', 'cmt-edas', 'cmt-iasted', 'conference-edas', 'cmt-ekaw', 'ekaw-iasted', 'edas-iasted', 'confOf-iasted', 'confOf-ekaw', 'edas-sigkdd', 'confOf-edas', 'conference-ekaw', 'conference-sigkdd', 'cmt-confOf', 'ekaw-sigkdd', 'conference-confOf', 'cmt-conference', 'confOf-sigkdd', 'cmt-sigkdd', 'conference-iasted']
# File: cmt.owl
# cmt
# Generated related text file: /home/serverKB/SIS/src/textExtraction/cmt.txt
# File: sigkdd.owl
# sigkdd
# Generated related text file: /home/serverKB/SIS/src/textExtraction/sigkdd.txt
# File: linklings.owl
# linklings
# Generated related text file: /home/serverKB/SIS/src/textExtraction/linklings.txt
# File: MyReview.owl
# MyReview
# Generated related text file: /home/serverKB/SIS/src/textExtraction/myreview.txt
# File: Cocus.owl
# Cocus
# Generated related text file: /home/serverKB/SIS/src/textExtraction/cocus.txt
# File: confOf.owl
# confOf
# Generated related text file: /home/serverKB/SIS/src/textExtraction/confof.txt
# File: edas.owl
# edas
# Generated related text file: /home/serverKB/SIS/src/textExtraction/edas.txt
# File: confious.owl
# confious
# Generated related text file: /home/serverKB/SIS/src/textExtraction/confious.txt
# File: ekaw.owl
# ekaw
# Generated related text file: /home/serverKB/SIS/src/textExtraction/ekaw.txt
# File: paperdyne.owl
# paperdyne
# Generated related text file: /home/serverKB/SIS/src/textExtraction/paperdyne.txt
# File: Conference.owl
# Conference
# Generated related text file: /home/serverKB/SIS/src/textExtraction/conference.txt
# File: PCS.owl
# PCS
# Generated related text file: /home/serverKB/SIS/src/textExtraction/pcs.txt
# File: crs_dr.owl
# crs_dr
# Generated related text file: /home/serverKB/SIS/src/textExtraction/crs_dr.txt
# File: MICRO.owl
# MICRO
# Generated related text file: /home/serverKB/SIS/src/textExtraction/micro.txt
# File: OpenConf.owl
# OpenConf
# Generated related text file: /home/serverKB/SIS/src/textExtraction/openconf.txt
# File: iasted.owl
# iasted
# Generated related text file: /home/serverKB/SIS/src/textExtraction/iasted.txt

# %%
sys.path = original_path

from src.evaluator import computator
from src.core import reader, onto_dict, split_by_caps,embedded_dict,myembed,matchrelated,topN
from src.core import remove_special_characters, matcher_of_indexes, RTXmatcher,SEMEMBmatcher

# %%
import pandas as pd

datas=pd.DataFrame()
for al in names:
    print(al)
    name1=al.split('-')[0]
    name2=al.split('-')[1]
    cmt=reader(absolute_path+'/'+name1+'.txt')
    ekaw=reader(absolute_path+'/'+name2+'.txt')
# Out:
# iasted-sigkdd
# edas-ekaw
# cmt-edas
# cmt-iasted
# conference-edas
# cmt-ekaw
# ekaw-iasted
# edas-iasted
# confOf-iasted
# confOf-ekaw
# edas-sigkdd
# confOf-edas
# conference-ekaw
# conference-sigkdd
# cmt-confOf
# ekaw-sigkdd
# conference-confOf
# cmt-conference
# confOf-sigkdd
# cmt-sigkdd
# conference-iasted

# %%
cmt
# Out:
# [['Conference_volume', ' Class', ' type: Class; subClassOf: Conference'],
#  ['has_a_location',
#   ' DatatypeProperty',
#   ' type: DatatypeProperty; domain: Conference_volume; range: string'],
#  ['Passive_conference_participant',
#   ' Class',
#   ' type: Class; subClassOf: Conference_participant; disjointWith: Active_conference_participant'],
#  ['Written_contribution',
#   ' Class',
#   ' type: Class; subClassOf: Nc2ecae667b7a46a38b27849e8baf0c96,Conference_contribution'],
#  ['Regular_contribution',
#   ' Class',
#   ' type: Class; equivalentClass: N8b6f4e6db9f1402c8ac24c3520426b8a; disjointWith: Invited_talk,Poster; subClassOf: Written_contribution'],
#  ['Chair',
#   ' Class',
#   ' type: Class; equivalentClass: N56fa33e4f8b2468abfa7a14684ca441f; subClassOf: Committee_member'],
#  ['Paper',
#   ' Class',
#   ' type: Class; subClassOf: Regular_contribution; disjointWith: Extended_abstract'],
#  ['has_a_committee_chair',
#   ' ObjectProperty',
#   ' type: ObjectProperty,FunctionalProperty; inverseOf: was_a_committee_chair_of; subPropertyOf: has_members; range: Chair; domain: Committee'],
#  ['has_a_publisher',
#   ' FunctionalProperty',
#   ' type: FunctionalProperty,ObjectProperty; range: Publisher; domain: Conference_proceedings; inverseOf: issues'],
#  ['has_a_review_expertise',
#   ' InverseFunctionalProperty',
#   ' type: InverseFunctionalProperty,ObjectProperty; domain: Submitted_contribution; inverseOf: has_a_submitted_contribution; range: Review_expertise'],
#  ['was_a_committe_co-chair_of',
#   ' ObjectProperty',
#   ' type: ObjectProperty; inverseOf: has_a_committee_co-chair; range: Committee; domain: Co-chair; subPropertyOf: was_a_member_of'],
#  ['has_tracks',
#   ' ObjectProperty',
#   ' type: ObjectProperty; subPropertyOf: has_parts; range: Track; domain: Conference_volume'],
#  ['Conference_contributor', ' Class', ' type: Class; subClassOf: Person'],
#  ['Active_conference_participant',
#   ' Class',
#   ' type: Class; subClassOf: Conference_contributor,N8ef70ad6cd494e3c8e9d371667b6aaf3,Conference_participant; disjointWith: Passive_conference_participant'],
#  ['N1c11aa3462064f8798dd86cc254f275b', ' Unknown', ''],
#  ['is_submitted_at',
#   ' ObjectProperty',
#   ' type: ObjectProperty; domain: Conference_contribution; range: Conference_volume; inverseOf: has_contributions'],
#  ['Ndbc8b647ee924d418865a8363d31647c', ' Unknown', ''],
#  ['has_been_assigned_a_review_reference',
#   ' InverseFunctionalProperty',
#   ' type: InverseFunctionalProperty,ObjectProperty; domain: Nab5e905a54704597af704c6d8358e10f; inverseOf: has_a_topic_or_a_submission_contribution; range: Review_preference'],
#  ['Na3835dc86c86479a80487a77741de68d', ' Unknown', ''],
#  ['Conference_part', ' Class', ' type: Class'],
#  ['has_a_volume',
#   ' FunctionalProperty',
#   ' type: FunctionalProperty,DatatypeProperty; range: int; domain: Conference_proceedings'],
#  ['is_a_date_of_acceptance_announcement',
#   ' FunctionalProperty',
#   ' type: FunctionalProperty,DatatypeProperty; domain: Important_dates; range: date'],
#  ['Poster',
#   ' Class',
#   ' type: Class; disjointWith: Invited_talk,Regular_contribution; subClassOf: Conference_contribution'],
#  ['N3f41ca49e6844c7d89bd4f346066c931', ' Unknown', ''],
#  ['N485c2d04b5504c7cbd9e71052e8c0631', ' Unknown', ''],
#  ['is_a_date_of_camera_ready_paper_submission',
#   ' FunctionalProperty',
#   ' type: FunctionalProperty,DatatypeProperty; range: date; domain: Important_dates'],
#  ['was_a_committee_of',
#   ' ObjectProperty',
#   ' type: ObjectProperty; inverseOf: has_a_commtitee; range: Conference_volume; domain: Committee'],
#  ['belongs_to_a_review_reference',
#   ' ObjectProperty',
#   ' type: ObjectProperty,InverseFunctionalProperty; domain: Topic; range: Review_preference'],
#  ['Conference_document', ' Class', ' type: Class'],
#  ['Contribution_1th-author',
#   ' Class',
#   ' type: Class; subClassOf: Regular_author; disjointWith: Contribution_co-author'],
#  ['has_a_date_of_issue',
#   ' DatatypeProperty',
#   ' type: DatatypeProperty,FunctionalProperty; domain: Conference_document; range: date'],
#  ['is_part_of_conference_volumes',
#   ' ObjectProperty',
#   ' type: ObjectProperty; inverseOf: has_parts; range: Conference_volume; domain: Conference_part'],
#  ['Regular_author',
#   ' Class',
#   ' type: Class; subClassOf: Conference_contributor; equivalentClass: N2e001e8578fa45e0922c8150302295ed'],
#  ['Call_for_paper', ' Class', ' type: Class; subClassOf: Conference_document'],
#  ['has_a_submitted_contribution',
#   ' ObjectProperty',
#   ' type: ObjectProperty,FunctionalProperty; range: Submitted_contribution; inverseOf: has_a_review_expertise; domain: Review_expertise'],
#  ['N7b3ec99c92864fbd8f06929b9621cc1b', ' Unknown', ''],
#  ['has_gender',
#   ' DatatypeProperty',
#   ' type: DatatypeProperty,FunctionalProperty; domain: Person; range: Nc844c70a4bf34046822bccd4ff0c3800'],
#  ['is_an_abstract_submission_date',
#   ' DatatypeProperty',
#   ' type: DatatypeProperty,FunctionalProperty; domain: Important_dates; range: date'],
#  ['was_an_organizing_committee_of',
#   ' ObjectProperty',
#   ' type: ObjectProperty,InverseFunctionalProperty; range: Conference_volume; inverseOf: has_an_organizing_committee; subPropertyOf: was_a_committee_of; domain: Organizing_committee'],
#  ['contributes',
#   ' ObjectProperty',
#   ' type: ObjectProperty; inverseOf: has_authors; domain: Person; range: Conference_document'],
#  ['has_tutorials',
#   ' ObjectProperty',
#   ' type: ObjectProperty; domain: Conference_volume; subPropertyOf: has_parts; range: Tutorial'],
#  ['Invited_talk',
#   ' Class',
#   ' type: Class; disjointWith: Poster,Regular_contribution; subClassOf: Presentation'],
#  ['N8b6f4e6db9f1402c8ac24c3520426b8a', ' Unknown', ''],
#  ['has_authors',
#   ' ObjectProperty',
#   ' type: ObjectProperty; domain: Conference_document; range: Person; inverseOf: contributes'],
#  ['has_a_review_reference_or_expertise',
#   ' ObjectProperty',
#   ' type: ObjectProperty; inverseOf: belongs_to_reviewers; range: Ndd4dbc9050c847f5999d908569a66df3; domain: Reviewer'],
#  ['Call_for_participation',
#   ' Class',
#   ' type: Class; subClassOf: Conference_document'],
#  ['invites_co-reviewers',
#   ' ObjectProperty',
#   ' type: ObjectProperty; domain: Reviewer; range: Reviewer; inverseOf: invited_by'],
#  ['has_an_abstract',
#   ' FunctionalProperty',
#   ' type: FunctionalProperty,ObjectProperty; range: Abstract; domain: Naa0381193b254e16ba292282b9edfd55; inverseOf: is_the_1th_part_of'],
#  ['Accepted_contribution',
#   ' Class',
#   ' type: Class; disjointWith: Rejected_contribution; subClassOf: Reviewed_contribution'],
#  ['Late_paid_applicant',
#   ' Class',
#   ' type: Class; subClassOf: Paid_applicant; disjointWith: Early_paid_applicant'],
#  ['N673e18a93c294a7abd7ee797e21e0ee4', ' Unknown', ''],
#  ['Organization', ' Class', ' type: Class'],
#  ['has_members',
#   ' ObjectProperty',
#   ' type: ObjectProperty; inverseOf: was_a_member_of; domain: Committee; range: Committee_member'],
#  ['issues',
#   ' InverseFunctionalProperty',
#   ' type: InverseFunctionalProperty,ObjectProperty; inverseOf: has_a_publisher; range: Conference_proceedings; domain: Publisher'],
#  ['has_a_URL',
#   ' FunctionalProperty',
#   ' type: FunctionalProperty,DatatypeProperty; domain: Conference_www; range: string'],
#  ['Conference_contribution',
#   ' Class',
#   ' type: Class; equivalentClass: N72b003728769491fa735ae61fda42951,Ne3797959f5614529a854c47c33380a6c; subClassOf: Conference_document'],
#  ['Paid_applicant',
#   ' Class',
#   ' type: Class; subClassOf: Registeered_applicant; equivalentClass: N485c2d04b5504c7cbd9e71052e8c0631'],
#  ['has_important_dates',
#   ' ObjectProperty',
#   ' type: ObjectProperty,FunctionalProperty; range: Important_dates; domain: Conference_volume; inverseOf: belong_to_a_conference_volume'],
#  ['Ne68c383e8ea94154ac10863c92ae5628', ' Unknown', ''],
#  ['Program_committee',
#   ' Class',
#   ' type: Class; subClassOf: Committee; disjointWith: Organizing_committee,Steering_committee'],
#  ['Reviewer', ' Class', ' type: Class; subClassOf: Person'],
#  ['Committee_member',
#   ' Class',
#   ' type: Class; equivalentClass: N8d189e1c79b545baa37998dcfa5ebc19; subClassOf: Person'],
#  ['Presentation',
#   ' Class',
#   ' type: Class; subClassOf: Conference_contribution'],
#  ['Nc2ecae667b7a46a38b27849e8baf0c96', ' Unknown', ''],
#  ['belong_to_a_conference_volume',
#   ' InverseFunctionalProperty',
#   ' type: InverseFunctionalProperty,ObjectProperty; range: Conference_volume; domain: Important_dates; inverseOf: has_important_dates'],
#  ['Invited_speaker',
#   ' Class',
#   ' type: Class; subClassOf: Conference_contributor; equivalentClass: N7ec5f6ac47ba41639be529dac94b49ee'],
#  ['Conference_announcement',
#   ' Class',
#   ' type: Class; subClassOf: Conference_document'],
#  ['Organizer',
#   ' Class',
#   ' type: Class; subClassOf: N1c11aa3462064f8798dd86cc254f275b,Thing'],
#  ['Publisher', ' Class', ' type: Class'],
#  ['Ncd91d246208b4e70a62fccd25414c588', ' Unknown', ''],
#  ['has_workshops',
#   ' ObjectProperty',
#   ' type: ObjectProperty; domain: Conference_volume; subPropertyOf: has_parts; range: Workshop'],
#  ['has_a_commtitee',
#   ' ObjectProperty',
#   ' type: ObjectProperty; inverseOf: was_a_committee_of; range: Committee; domain: Conference_volume'],
#  ['Important_dates', ' Class', ' type: Class'],
#  ['has_contributions',
#   ' ObjectProperty',
#   ' type: ObjectProperty; domain: Conference_volume; inverseOf: is_submitted_at; range: Conference_contribution'],
#  ['is_a_full_paper_submission_date',
#   ' DatatypeProperty',
#   ' type: DatatypeProperty,FunctionalProperty; range: date; domain: Important_dates'],
#  ['Information_for_participants',
#   ' Class',
#   ' type: Class; subClassOf: Conference_document'],
#  ['Review_expertise',
#   ' Class',
#   ' type: Class; subClassOf: Thing,N8b3ba5951988490f9a8f11071ebc6860,N86d761aa77cd467eb53a16256a6bc587'],
#  ['N44b2bb2a06a84dbdb6589041a0890c73', ' Unknown', ''],
#  ['Person', ' Class', ' type: Class'],
#  ['N8ef70ad6cd494e3c8e9d371667b6aaf3', ' Unknown', ''],
#  ['has_an_email',
#   ' DatatypeProperty',
#   ' type: DatatypeProperty; range: string; domain: Person'],
#  ['is_a_topis_of_conference_parts',
#   ' ObjectProperty',
#   ' type: ObjectProperty; inverseOf: has_a_track-workshop-tutorial_topic; range: Conference_part; domain: Topic'],
#  ['is_given_by',
#   ' ObjectProperty',
#   ' type: ObjectProperty; range: Active_conference_participant; domain: Presentation; inverseOf: gives_presentations'],
#  ['Review',
#   ' Class',
#   ' type: Class; subClassOf: Na3306a7dc33943e2ab97ad7a4470f0d0,Conference_document'],
#  ['has_a_program_committee',
#   ' FunctionalProperty',
#   ' type: FunctionalProperty,ObjectProperty; subPropertyOf: has_a_commtitee; domain: Conference_volume; inverseOf: was_a_program_committee_of; range: Program_committee'],
#  ['Early_paid_applicant',
#   ' Class',
#   ' type: Class; disjointWith: Late_paid_applicant; subClassOf: Paid_applicant'],
#  ['Contribution_co-author',
#   ' Class',
#   ' type: Class; subClassOf: Regular_author; disjointWith: Contribution_1th-author'],
#  ['Reviewed_contribution',
#   ' Class',
#   ' type: Class; subClassOf: Submitted_contribution; equivalentClass: N44b2bb2a06a84dbdb6589041a0890c73'],
#  ['has_a_track-workshop-tutorial_chair',
#   ' FunctionalProperty',
#   ' type: FunctionalProperty,ObjectProperty; inverseOf: was_a_track-workshop_chair_of; range: Track-workshop_chair; domain: Conference_part'],
#  ['Track',
#   ' Class',
#   ' type: Class; subClassOf: Conference_part; disjointWith: Workshop,Tutorial'],
#  ['Conference_proceedings', ' Class', ' type: Class'],
#  ['has_a_name',
#   ' DatatypeProperty',
#   ' type: DatatypeProperty,FunctionalProperty; domain: Ndbc8b647ee924d418865a8363d31647c; range: string'],
#  ['Review_preference',
#   ' Class',
#   ' type: Class; subClassOf: Thing,Nd29f62f8867545a98ef307019e868588,N16d5326e698048059b1d45a305a19a13'],
#  ['has_a_track-workshop-tutorial_topic',
#   ' ObjectProperty',
#   ' type: ObjectProperty; inverseOf: is_a_topis_of_conference_parts; range: Topic; domain: Conference_part'],
#  ['N72b003728769491fa735ae61fda42951', ' Unknown', ''],
#  ['Registeered_applicant',
#   ' Class',
#   ' type: Class; subClassOf: Conference_applicant'],
#  ['Committee',
#   ' Class',
#   ' type: Class; equivalentClass: Ncd91d246208b4e70a62fccd25414c588'],
#  ['has_an_expertise',
#   ' FunctionalProperty',
#   ' type: FunctionalProperty,DatatypeProperty; domain: Review_expertise; range: N1d169542939b4524b7ac10fbaf953347'],
#  ['has_the_last_name',
#   ' FunctionalProperty',
#   ' type: FunctionalProperty,DatatypeProperty; range: string; domain: Person'],
#  ['has_a_review',
#   ' ObjectProperty',
#   ' type: ObjectProperty,InverseFunctionalProperty; domain: Reviewed_contribution; inverseOf: reviews; range: Review'],
#  ['was_a_track-workshop_chair_of',
#   ' ObjectProperty',
#   ' type: ObjectProperty,InverseFunctionalProperty; inverseOf: has_a_track-workshop-tutorial_chair; range: Conference_part; domain: Track-workshop_chair'],
#  ['Ndd4dbc9050c847f5999d908569a66df3', ' Unknown', ''],
#  ['Workshop',
#   ' Class',
#   ' type: Class; subClassOf: Conference_part; disjointWith: Tutorial,Track'],
#  ['has_a_topic_or_a_submission_contribution',
#   ' ObjectProperty',
#   ' type: ObjectProperty,FunctionalProperty; inverseOf: has_been_assigned_a_review_reference; range: N673e18a93c294a7abd7ee797e21e0ee4; domain: Review_preference'],
#  ['was_a_program_committee_of',
#   ' ObjectProperty',
#   ' type: ObjectProperty,InverseFunctionalProperty; domain: Program_committee; range: Conference_volume; subPropertyOf: was_a_committee_of; inverseOf: has_a_program_committee'],
#  ['has_an_ISBN',
#   ' DatatypeProperty',
#   ' type: DatatypeProperty,FunctionalProperty; range: string; domain: Conference_proceedings'],
#  ['Nb86ee2efd08b42ac93c0cd8e8306b757', ' Unknown', ''],
#  ['Rejected_contribution',
#   ' Class',
#   ' type: Class; disjointWith: Accepted_contribution; subClassOf: Reviewed_contribution'],
#  ['has_a_degree',
#   ' DatatypeProperty',
#   ' type: DatatypeProperty,FunctionalProperty; domain: Review_preference; range: int'],
#  ['has_a_committee_co-chair',
#   ' ObjectProperty',
#   ' type: ObjectProperty; subPropertyOf: has_members; domain: Committee; range: Co-chair; inverseOf: was_a_committe_co-chair_of'],
#  ['Ne3797959f5614529a854c47c33380a6c', ' Unknown', ''],
#  ['has_an_organizing_committee',
#   ' ObjectProperty',
#   ' type: ObjectProperty,FunctionalProperty; subPropertyOf: has_a_commtitee; inverseOf: was_an_organizing_committee_of; range: Organizing_committee; domain: Conference_volume'],
#  ['gives_presentations',
#   ' ObjectProperty',
#   ' type: ObjectProperty; domain: Active_conference_participant; range: Presentation; inverseOf: is_given_by'],
#  ['has_the_first_name',
#   ' DatatypeProperty',
#   ' type: DatatypeProperty; range: string; domain: Person'],
#  ['Topic', ' Class', ' type: Class'],
#  ['was_a_member_of',
#   ' ObjectProperty',
#   ' type: ObjectProperty; domain: Committee_member; inverseOf: has_members; range: Committee'],
#  ['Steering_committee',
#   ' Class',
#   ' type: Class; disjointWith: Program_committee,Organizing_committee; subClassOf: Committee'],
#  ['Extended_abstract',
#   ' Class',
#   ' type: Class; disjointWith: Paper; subClassOf: Regular_contribution'],
#  ['is_a_starting_date',
#   ' FunctionalProperty',
#   ' type: FunctionalProperty,DatatypeProperty; domain: Important_dates; range: date'],
#  ['Abstract', ' Class', ' type: Class; subClassOf: Extended_abstract'],
#  ['invited_by',
#   ' ObjectProperty',
#   ' type: ObjectProperty; range: Reviewer; inverseOf: invites_co-reviewers; domain: Reviewer'],
#  ['Co-chair',
#   ' Class',
#   ' type: Class; equivalentClass: N3b7a6a2bda06444a86299691108d321a; subClassOf: Committee_member'],
#  ['Conference_applicant', ' Class', ' type: Class; subClassOf: Person'],
#  ['was_a_steering_committee_of',
#   ' ObjectProperty',
#   ' type: ObjectProperty,InverseFunctionalProperty; subPropertyOf: was_a_committee_of; domain: Steering_committee; inverseOf: has_a_steering_committee; range: Conference_volume'],
#  ['was_a_committee_chair_of',
#   ' InverseFunctionalProperty',
#   ' type: InverseFunctionalProperty,ObjectProperty; subPropertyOf: was_a_member_of; inverseOf: has_a_committee_chair; range: Committee; domain: Chair'],
#  ['Naa0381193b254e16ba292282b9edfd55', ' Unknown', ''],
#  ['Conference', ' Class', ' type: Class'],
#  ['N2e001e8578fa45e0922c8150302295ed', ' Unknown', ''],
#  ['Nab5e905a54704597af704c6d8358e10f', ' Unknown', ''],
#  ['is_the_1th_part_of',
#   ' InverseFunctionalProperty',
#   ' type: InverseFunctionalProperty,ObjectProperty; inverseOf: has_an_abstract; domain: Abstract; range: Ne68c383e8ea94154ac10863c92ae5628'],
#  ['reviews',
#   ' FunctionalProperty',
#   ' type: FunctionalProperty,ObjectProperty; domain: Review; range: Reviewed_contribution; inverseOf: has_a_review'],
#  ['is_an_ending_date',
#   ' FunctionalProperty',
#   ' type: FunctionalProperty,DatatypeProperty; range: date; domain: Important_dates'],
#  ['Submitted_contribution',
#   ' Class',
#   ' type: Class; subClassOf: N7b3ec99c92864fbd8f06929b9621cc1b,Written_contribution'],
#  ['Organizing_committee',
#   ' Class',
#   ' type: Class; subClassOf: Committee; disjointWith: Program_committee,Steering_committee'],
#  ['belongs_to_reviewers',
#   ' ObjectProperty',
#   ' type: ObjectProperty; range: Reviewer; inverseOf: has_a_review_reference_or_expertise; domain: Nb86ee2efd08b42ac93c0cd8e8306b757'],
#  ['Camera_ready_contribution',
#   ' Class',
#   ' type: Class; subClassOf: Accepted_contribution'],
#  ['Tutorial',
#   ' Class',
#   ' type: Class; disjointWith: Track,Workshop; subClassOf: Conference_part'],
#  ['has_parts',
#   ' ObjectProperty',
#   ' type: ObjectProperty; inverseOf: is_part_of_conference_volumes; range: Conference_part; domain: Conference_volume'],
#  ['Conference_www', ' Class', ' type: Class; subClassOf: Conference_document'],
#  ['Conference_fees', ' Class', ' type: Class'],
#  ['Conference_participant',
#   ' Class',
#   ' type: Class; equivalentClass: Ne9a49bf687f14ccaababdb0ca3b90116; subClassOf: Person'],
#  ['Ne9a49bf687f14ccaababdb0ca3b90116', ' Unknown', ''],
#  ['N2bcfcaafadc44b2b86d865b4b4345186', ' Unknown', ''],
#  ['Track-workshop_chair',
#   ' Class',
#   ' type: Class; equivalentClass: N372186ca338a4fb28e5086d6d412b348; subClassOf: Person'],
#  ['has_a_steering_committee',
#   ' ObjectProperty',
#   ' type: ObjectProperty,FunctionalProperty; inverseOf: was_a_steering_committee_of; subPropertyOf: has_a_commtitee; range: Steering_committee; domain: Conference_volume']]

# %%
reade
